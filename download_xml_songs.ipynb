# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup

# %% [markdown]
# ### Crawling xml songs database:

# %% [markdown]
# We will start from a set of xml song files, that explicitly describe harmony, beat, melody, tempo and other musical features. After that, we use them in order to create a database with audio content, converting xml files to midi. It means that, initially, we are going to work with synthetically generated data, due to its facility to synchronize audio and chord labels.

# %% [markdown]
# #### Jazz repo:

# %%
url_base = 'https://effendi.me/jazz/repo/'
iters = ['I/', 'II/', 'III/', 'IV_Part-1/', 'IV_Part-2/', 'V/']
url_list = []
for i in iters:
    url = url_base + i
    site = requests.get(url)
    soup = BeautifulSoup(site.text, 'lxml')
#     print(url, len(soup.find_all('a')))
    songs = soup.find_all('a')
    for link in songs:
        link = link.get('href')
#         print(links)
        if link.startswith('?'):
            pass
        else:
            url_list.append(url+link)

# %%
url_list = [l for l in url_list if l.endswith('xml')]
#url_list

# %% [markdown]
# Saving list of links in a txt file:

# %%
with open('corpus/xml_songs.txt', 'w') as f:
    for item in url_list:
        f.write("%s\n" % item)

# %% [markdown]
# #### Downloading xml corpus

# %%
! wget -i corpus/xml_songs.txt --directory-prefix=corpus/xml
# Out:
# --2022-06-16 17:07:54--  https://effendi.me/jazz/repo/I/630blues.xml
# Resolvendo effendi.me (effendi.me)... 165.227.6.59
# Conectando-se a effendi.me (effendi.me)|165.227.6.59|:443... conectado.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 40868 (40K) [application/xml]
# Salvando em: “corpus/xml/test/630blues.xml”
#
# 630blues.xml        100%[===================>]  39,91K   192KB/s    em 0,2s
#
# 2022-06-16 17:07:55 (192 KB/s) - “corpus/xml/test/630blues.xml” salvo [40868/40868]
#
# --2022-06-16 17:07:55--  https://effendi.me/jazz/repo/I/728.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 42919 (42K) [application/xml]
# Salvando em: “corpus/xml/test/728.xml”
#
# 728.xml             100%[===================>]  41,91K  --.-KB/s    em 0,002s
#
# 2022-06-16 17:07:55 (18,0 MB/s) - “corpus/xml/test/728.xml” salvo [42919/42919]
#
# --2022-06-16 17:07:55--  https://effendi.me/jazz/repo/I/1974%20Blues.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 61441 (60K) [application/xml]
# Salvando em: “corpus/xml/test/1974 Blues.xml”
#
# 1974 Blues.xml      100%[===================>]  60,00K  --.-KB/s    em 0,01s
#
# 2022-06-16 17:07:56 (5,36 MB/s) - “corpus/xml/test/1974 Blues.xml” salvo [61441/61441]
#
# --2022-06-16 17:07:56--  https://effendi.me/jazz/repo/I/AllBlues%201.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 37310 (36K) [application/xml]
# Salvando em: “corpus/xml/test/AllBlues 1.xml”
#
# AllBlues 1.xml      100%[===================>]  36,44K  --.-KB/s    em 0,006s
#
# 2022-06-16 17:07:56 (6,33 MB/s) - “corpus/xml/test/AllBlues 1.xml” salvo [37310/37310]
#
# --2022-06-16 17:07:56--  https://effendi.me/jazz/repo/I/Ambidextrous.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 84106 (82K) [application/xml]
# Salvando em: “corpus/xml/test/Ambidextrous.xml”
#
# Ambidextrous.xml    100%[===================>]  82,13K  --.-KB/s    em 0,009s
#
# 2022-06-16 17:07:56 (9,15 MB/s) - “corpus/xml/test/Ambidextrous.xml” salvo [84106/84106]
#
# --2022-06-16 17:07:56--  https://effendi.me/jazz/repo/I/Amsterdam%20After%20DarkII.5.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 58808 (57K) [application/xml]
# Salvando em: “corpus/xml/test/Amsterdam After DarkII.5.xml”
#
# Amsterdam After Dar 100%[===================>]  57,43K  --.-KB/s    em 0,006s
#
# 2022-06-16 17:07:56 (9,10 MB/s) - “corpus/xml/test/Amsterdam After DarkII.5.xml” salvo [58808/58808]
#
# --2022-06-16 17:07:56--  https://effendi.me/jazz/repo/I/A%20smooth%20One.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 76337 (75K) [application/xml]
# Salvando em: “corpus/xml/test/A smooth One.xml”
#
# A smooth One.xml    100%[===================>]  74,55K  36,4KB/s    em 2,0s
#
# 2022-06-16 17:07:58 (36,4 KB/s) - “corpus/xml/test/A smooth One.xml” salvo [76337/76337]
#
# --2022-06-16 17:07:58--  https://effendi.me/jazz/repo/I/Ballad.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 52953 (52K) [application/xml]
# Salvando em: “corpus/xml/test/Ballad.xml”
#
# Ballad.xml          100%[===================>]  51,71K  57,8KB/s    em 0,9s
#
# 2022-06-16 17:08:00 (57,8 KB/s) - “corpus/xml/test/Ballad.xml” salvo [52953/52953]
#
# --2022-06-16 17:08:00--  https://effendi.me/jazz/repo/I/Blues%20For%20Junior.Pyramid.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 34946 (34K) [application/xml]
# Salvando em: “corpus/xml/test/Blues For Junior.Pyramid.xml”
#
# Blues For Junior.Py 100%[===================>]  34,13K  --.-KB/s    em 0,004s
#
# 2022-06-16 17:08:00 (8,46 MB/s) - “corpus/xml/test/Blues For Junior.Pyramid.xml” salvo [34946/34946]
#
# --2022-06-16 17:08:00--  https://effendi.me/jazz/repo/I/Blues%20after%20Dark%20II.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 79520 (78K) [application/xml]
# Salvando em: “corpus/xml/test/Blues after Dark II.xml”
#
# Blues after Dark II 100%[===================>]  77,66K  40,1KB/s    em 1,9s
#
# 2022-06-16 17:08:02 (40,1 KB/s) - “corpus/xml/test/Blues after Dark II.xml” salvo [79520/79520]
#
# --2022-06-16 17:08:02--  https://effendi.me/jazz/repo/I/Blues%20for%20PK.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 34263 (33K) [application/xml]
# Salvando em: “corpus/xml/test/Blues for PK.xml”
#
# Blues for PK.xml    100%[===================>]  33,46K   148KB/s    em 0,2s
#
# 2022-06-16 17:08:02 (148 KB/s) - “corpus/xml/test/Blues for PK.xml” salvo [34263/34263]
#
# --2022-06-16 17:08:02--  https://effendi.me/jazz/repo/I/Bluesinthebasement.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 46489 (45K) [application/xml]
# Salvando em: “corpus/xml/test/Bluesinthebasement.xml”
#
# Bluesinthebasement. 100%[===================>]  45,40K  --.-KB/s    em 0,005s
#
# 2022-06-16 17:08:03 (9,64 MB/s) - “corpus/xml/test/Bluesinthebasement.xml” salvo [46489/46489]
#
# --2022-06-16 17:08:03--  https://effendi.me/jazz/repo/I/Bold%20and%20Black.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 34427 (34K) [application/xml]
# Salvando em: “corpus/xml/test/Bold and Black.xml”
#
# Bold and Black.xml  100%[===================>]  33,62K  --.-KB/s    em 0,002s
#
# 2022-06-16 17:08:03 (18,2 MB/s) - “corpus/xml/test/Bold and Black.xml” salvo [34427/34427]
#
# --2022-06-16 17:08:03--  https://effendi.me/jazz/repo/I/Boogie%20Stop%20Shuffle.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 127817 (125K) [application/xml]
# Salvando em: “corpus/xml/test/Boogie Stop Shuffle.xml”
#
# Boogie Stop Shuffle 100%[===================>] 124,82K   329KB/s    em 0,4s
#
# 2022-06-16 17:08:03 (329 KB/s) - “corpus/xml/test/Boogie Stop Shuffle.xml” salvo [127817/127817]
#
# --2022-06-16 17:08:03--  https://effendi.me/jazz/repo/I/Boogie%20Woogie%20Bossa%20Nova.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 28835 (28K) [application/xml]
# Salvando em: “corpus/xml/test/Boogie Woogie Bossa Nova.xml”
#
# Boogie Woogie Bossa 100%[===================>]  28,16K  --.-KB/s    em 0,001s
#
# 2022-06-16 17:08:04 (26,3 MB/s) - “corpus/xml/test/Boogie Woogie Bossa Nova.xml” salvo [28835/28835]
#
# --2022-06-16 17:08:04--  https://effendi.me/jazz/repo/I/Cantaloupe%20Island.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 29085 (28K) [application/xml]
# Salvando em: “corpus/xml/test/Cantaloupe Island.xml”
#
# Cantaloupe Island.x 100%[===================>]  28,40K  --.-KB/s    em 0s
#
# 2022-06-16 17:08:04 (102 MB/s) - “corpus/xml/test/Cantaloupe Island.xml” salvo [29085/29085]
#
# --2022-06-16 17:08:04--  https://effendi.me/jazz/repo/I/Chicago%20Seranade.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 60856 (59K) [application/xml]
# Salvando em: “corpus/xml/test/Chicago Seranade.xml”
#
# Chicago Seranade.xm 100%[===================>]  59,43K   319KB/s    em 0,2s
#
# 2022-06-16 17:08:04 (319 KB/s) - “corpus/xml/test/Chicago Seranade.xml” salvo [60856/60856]
#
# --2022-06-16 17:08:04--  https://effendi.me/jazz/repo/I/Cissy%20Strut%20III.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 35572 (35K) [application/xml]
# Salvando em: “corpus/xml/test/Cissy Strut III.xml”
#
# Cissy Strut III.xml 100%[===================>]  34,74K  --.-KB/s    em 0,004s
#
# 2022-06-16 17:08:04 (8,43 MB/s) - “corpus/xml/test/Cissy Strut III.xml” salvo [35572/35572]
#
# --2022-06-16 17:08:04--  https://effendi.me/jazz/repo/I/Cissy%20Strut%20IV.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 49394 (48K) [application/xml]
# Salvando em: “corpus/xml/test/Cissy Strut IV.xml”
#
# Cissy Strut IV.xml  100%[===================>]  48,24K   123KB/s    em 0,4s
#
# 2022-06-16 17:08:05 (123 KB/s) - “corpus/xml/test/Cissy Strut IV.xml” salvo [49394/49394]
#
# --2022-06-16 17:08:05--  https://effendi.me/jazz/repo/I/Clockwise.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 51717 (51K) [application/xml]
# Salvando em: “corpus/xml/test/Clockwise.xml”
#
# Clockwise.xml       100%[===================>]  50,50K   248KB/s    em 0,2s
#
# 2022-06-16 17:08:05 (248 KB/s) - “corpus/xml/test/Clockwise.xml” salvo [51717/51717]
#
# --2022-06-16 17:08:05--  https://effendi.me/jazz/repo/I/Cold%20Duck%20B%20with%20bass.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 57599 (56K) [application/xml]
# Salvando em: “corpus/xml/test/Cold Duck B with bass.xml”
#
# Cold Duck B with ba 100%[===================>]  56,25K   290KB/s    em 0,2s
#
# 2022-06-16 17:08:06 (290 KB/s) - “corpus/xml/test/Cold Duck B with bass.xml” salvo [57599/57599]
#
# --2022-06-16 17:08:06--  https://effendi.me/jazz/repo/I/Cold%20duck%20Lead.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 33474 (33K) [application/xml]
# Salvando em: “corpus/xml/test/Cold duck Lead.xml”
#
# Cold duck Lead.xml  100%[===================>]  32,69K  --.-KB/s    em 0,005s
#
# 2022-06-16 17:08:06 (6,33 MB/s) - “corpus/xml/test/Cold duck Lead.xml” salvo [33474/33474]
#
# --2022-06-16 17:08:06--  https://effendi.me/jazz/repo/I/Crisis.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 80951 (79K) [application/xml]
# Salvando em: “corpus/xml/test/Crisis.xml”
#
# Crisis.xml          100%[===================>]  79,05K   385KB/s    em 0,2s
#
# 2022-06-16 17:08:07 (385 KB/s) - “corpus/xml/test/Crisis.xml” salvo [80951/80951]
#
# --2022-06-16 17:08:07--  https://effendi.me/jazz/repo/I/CrisisC%23.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 84557 (83K) [application/xml]
# Salvando em: “corpus/xml/test/CrisisC#.xml”
#
# CrisisC#.xml        100%[===================>]  82,58K   358KB/s    em 0,2s
#
# 2022-06-16 17:08:07 (358 KB/s) - “corpus/xml/test/CrisisC#.xml” salvo [84557/84557]
#
# --2022-06-16 17:08:07--  https://effendi.me/jazz/repo/I/Cryin%20Blues.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 42026 (41K) [application/xml]
# Salvando em: “corpus/xml/test/Cryin Blues.xml”
#
# Cryin Blues.xml     100%[===================>]  41,04K  --.-KB/s    em 0,001s
#
# 2022-06-16 17:08:07 (36,1 MB/s) - “corpus/xml/test/Cryin Blues.xml” salvo [42026/42026]
#
# --2022-06-16 17:08:07--  https://effendi.me/jazz/repo/I/Dangerous%20Curves%20A.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 128140 (125K) [application/xml]
# Salvando em: “corpus/xml/test/Dangerous Curves A.xml”
#
# Dangerous Curves A. 100%[===================>] 125,14K   300KB/s    em 0,4s
#
# 2022-06-16 17:08:08 (300 KB/s) - “corpus/xml/test/Dangerous Curves A.xml” salvo [128140/128140]
#
# --2022-06-16 17:08:08--  https://effendi.me/jazz/repo/I/Dangerous%20Curves%20B.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 94712 (92K) [application/xml]
# Salvando em: “corpus/xml/test/Dangerous Curves B.xml”
#
# Dangerous Curves B. 100%[===================>]  92,49K   227KB/s    em 0,4s
#
# 2022-06-16 17:08:09 (227 KB/s) - “corpus/xml/test/Dangerous Curves B.xml” salvo [94712/94712]
#
# --2022-06-16 17:08:09--  https://effendi.me/jazz/repo/I/Greenonions.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 43778 (43K) [application/xml]
# Salvando em: “corpus/xml/test/Greenonions.xml”
#
# Greenonions.xml     100%[===================>]  42,75K   212KB/s    em 0,2s
#
# 2022-06-16 17:08:09 (212 KB/s) - “corpus/xml/test/Greenonions.xml” salvo [43778/43778]
#
# --2022-06-16 17:08:09--  https://effendi.me/jazz/repo/I/Groovy%20Samba.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 44758 (44K) [application/xml]
# Salvando em: “corpus/xml/test/Groovy Samba.xml”
#
# Groovy Samba.xml    100%[===================>]  43,71K   217KB/s    em 0,2s
#
# 2022-06-16 17:08:09 (217 KB/s) - “corpus/xml/test/Groovy Samba.xml” salvo [44758/44758]
#
# --2022-06-16 17:08:09--  https://effendi.me/jazz/repo/I/Hattie%20Wall%20-%20001%20Alto%20Sax%201.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 61130 (60K) [application/xml]
# Salvando em: “corpus/xml/test/Hattie Wall - 001 Alto Sax 1.xml”
#
# Hattie Wall - 001 A 100%[===================>]  59,70K   293KB/s    em 0,2s
#
# 2022-06-16 17:08:10 (293 KB/s) - “corpus/xml/test/Hattie Wall - 001 Alto Sax 1.xml” salvo [61130/61130]
#
# --2022-06-16 17:08:10--  https://effendi.me/jazz/repo/I/Hattie%20Wall%20-%20002%20Alto%20Sax%202.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 77671 (76K) [application/xml]
# Salvando em: “corpus/xml/test/Hattie Wall - 002 Alto Sax 2.xml”
#
# Hattie Wall - 002 A 100%[===================>]  75,85K   375KB/s    em 0,2s
#
# 2022-06-16 17:08:10 (375 KB/s) - “corpus/xml/test/Hattie Wall - 002 Alto Sax 2.xml” salvo [77671/77671]
#
# --2022-06-16 17:08:10--  https://effendi.me/jazz/repo/I/Hattie%20Wall%20-%20003%20Tenor%20Sax.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 77516 (76K) [application/xml]
# Salvando em: “corpus/xml/test/Hattie Wall - 003 Tenor Sax.xml”
#
# Hattie Wall - 003 T 100%[===================>]  75,70K   366KB/s    em 0,2s
#
# 2022-06-16 17:08:11 (366 KB/s) - “corpus/xml/test/Hattie Wall - 003 Tenor Sax.xml” salvo [77516/77516]
#
# --2022-06-16 17:08:11--  https://effendi.me/jazz/repo/I/Hattie%20Wall%20-%20004%20Mallets.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 83219 (81K) [application/xml]
# Salvando em: “corpus/xml/test/Hattie Wall - 004 Mallets.xml”
#
# Hattie Wall - 004 M 100%[===================>]  81,27K   202KB/s    em 0,4s
#
# 2022-06-16 17:08:11 (202 KB/s) - “corpus/xml/test/Hattie Wall - 004 Mallets.xml” salvo [83219/83219]
#
# --2022-06-16 17:08:11--  https://effendi.me/jazz/repo/I/Hattie%20Wall%20-%20005%20Baritone%20Sax.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 108884 (106K) [application/xml]
# Salvando em: “corpus/xml/test/Hattie Wall - 005 Baritone Sax.xml”
#
# Hattie Wall - 005 B 100%[===================>] 106,33K   207KB/s    em 0,5s
#
# 2022-06-16 17:08:12 (207 KB/s) - “corpus/xml/test/Hattie Wall - 005 Baritone Sax.xml” salvo [108884/108884]
#
# --2022-06-16 17:08:12--  https://effendi.me/jazz/repo/I/Hattie%20Wall%20-%20006%20Drum%20Set.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 16660 (16K) [application/xml]
# Salvando em: “corpus/xml/test/Hattie Wall - 006 Drum Set.xml”
#
# Hattie Wall - 006 D 100%[===================>]  16,27K  --.-KB/s    em 0,001s
#
# 2022-06-16 17:08:12 (20,6 MB/s) - “corpus/xml/test/Hattie Wall - 006 Drum Set.xml” salvo [16660/16660]
#
# --2022-06-16 17:08:12--  https://effendi.me/jazz/repo/I/Hattie%20Wall.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 400082 (391K) [application/xml]
# Salvando em: “corpus/xml/test/Hattie Wall.xml”
# Hattie Wall.xml     100%[===================>] 390,71K   191KB/s    em 2,0s
#
# 2022-06-16 17:08:14 (191 KB/s) - “corpus/xml/test/Hattie Wall.xml” salvo [400082/400082]
#
# --2022-06-16 17:08:14--  https://effendi.me/jazz/repo/I/IDWNOBY.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 56160 (55K) [application/xml]
# Salvando em: “corpus/xml/test/IDWNOBY.xml”
#
# IDWNOBY.xml         100%[===================>]  54,84K   295KB/s    em 0,2s
#
# 2022-06-16 17:08:15 (295 KB/s) - “corpus/xml/test/IDWNOBY.xml” salvo [56160/56160]
#
# --2022-06-16 17:08:15--  https://effendi.me/jazz/repo/I/IdleMoments.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 35635 (35K) [application/xml]
# Salvando em: “corpus/xml/test/IdleMoments.xml”
#
# IdleMoments.xml     100%[===================>]  34,80K  --.-KB/s    em 0s
#
# 2022-06-16 17:08:15 (70,2 MB/s) - “corpus/xml/test/IdleMoments.xml” salvo [35635/35635]
#
# --2022-06-16 17:08:15--  https://effendi.me/jazz/repo/I/Instant%20Death.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 37636 (37K) [application/xml]
# Salvando em: “corpus/xml/test/Instant Death.xml”
#
# Instant Death.xml   100%[===================>]  36,75K  --.-KB/s    em 0,003s
#
# 2022-06-16 17:08:15 (11,1 MB/s) - “corpus/xml/test/Instant Death.xml” salvo [37636/37636]
#
# --2022-06-16 17:08:15--  https://effendi.me/jazz/repo/I/It's%20All%20Right%20Now.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 34278 (33K) [application/xml]
# Salvando em: “corpus/xml/test/It's All Right Now.xml”
#
# It's All Right Now. 100%[===================>]  33,47K  --.-KB/s    em 0,004s
#
# 2022-06-16 17:08:15 (7,80 MB/s) - “corpus/xml/test/It's All Right Now.xml” salvo [34278/34278]
#
# --2022-06-16 17:08:15--  https://effendi.me/jazz/repo/I/James%20Bond.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 101227 (99K) [application/xml]
# Salvando em: “corpus/xml/test/James Bond.xml”
#
# James Bond.xml      100%[===================>]  98,85K   241KB/s    em 0,4s
#
# 2022-06-16 17:08:16 (241 KB/s) - “corpus/xml/test/James Bond.xml” salvo [101227/101227]
#
# --2022-06-16 17:08:16--  https://effendi.me/jazz/repo/I/Jean%20De%20Fleur.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 167787 (164K) [application/xml]
# Salvando em: “corpus/xml/test/Jean De Fleur.xml”
#
# Jean De Fleur.xml   100%[===================>] 163,85K   232KB/s    em 0,7s
#
# 2022-06-16 17:08:17 (232 KB/s) - “corpus/xml/test/Jean De Fleur.xml” salvo [167787/167787]
#
# --2022-06-16 17:08:17--  https://effendi.me/jazz/repo/I/Jive%20Samba.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 55539 (54K) [application/xml]
# Salvando em: “corpus/xml/test/Jive Samba.xml”
#
# Jive Samba.xml      100%[===================>]  54,24K   235KB/s    em 0,2s
#
# 2022-06-16 17:08:17 (235 KB/s) - “corpus/xml/test/Jive Samba.xml” salvo [55539/55539]
#
# --2022-06-16 17:08:17--  https://effendi.me/jazz/repo/I/Just%20the%20Two%20of%20Us.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 54876 (54K) [application/xml]
# Salvando em: “corpus/xml/test/Just the Two of Us.xml”
#
# Just the Two of Us. 100%[===================>]  53,59K   290KB/s    em 0,2s
#
# 2022-06-16 17:08:18 (290 KB/s) - “corpus/xml/test/Just the Two of Us.xml” salvo [54876/54876]
#
# --2022-06-16 17:08:18--  https://effendi.me/jazz/repo/I/ListenHereNew.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 34783 (34K) [application/xml]
# Salvando em: “corpus/xml/test/ListenHereNew.xml”
#
# ListenHereNew.xml   100%[===================>]  33,97K  --.-KB/s    em 0s
#
# 2022-06-16 17:08:18 (90,3 MB/s) - “corpus/xml/test/ListenHereNew.xml” salvo [34783/34783]
#
# --2022-06-16 17:08:18--  https://effendi.me/jazz/repo/I/Love%20For%20Sale.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 87570 (86K) [application/xml]
# Salvando em: “corpus/xml/test/Love For Sale.xml”
#
# Love For Sale.xml   100%[===================>]  85,52K   209KB/s    em 0,4s
#
# 2022-06-16 17:08:19 (209 KB/s) - “corpus/xml/test/Love For Sale.xml” salvo [87570/87570]
#
# --2022-06-16 17:08:19--  https://effendi.me/jazz/repo/I/Lovely%20is%20Today.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 29177 (28K) [application/xml]
# Salvando em: “corpus/xml/test/Lovely is Today.xml”
#
# Lovely is Today.xml 100%[===================>]  28,49K  --.-KB/s    em 0s
#
# 2022-06-16 17:08:19 (327 MB/s) - “corpus/xml/test/Lovely is Today.xml” salvo [29177/29177]
#
# --2022-06-16 17:08:19--  https://effendi.me/jazz/repo/I/Mating%20Call.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 66972 (65K) [application/xml]
# Salvando em: “corpus/xml/test/Mating Call.xml”
#
# Mating Call.xml     100%[===================>]  65,40K   318KB/s    em 0,2s
#
# 2022-06-16 17:08:19 (318 KB/s) - “corpus/xml/test/Mating Call.xml” salvo [66972/66972]
#
# --2022-06-16 17:08:19--  https://effendi.me/jazz/repo/I/Mean%20GreansII.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 86921 (85K) [application/xml]
# Salvando em: “corpus/xml/test/Mean GreansII.xml”
#
# Mean GreansII.xml   100%[===================>]  84,88K   207KB/s    em 0,4s
#
# 2022-06-16 17:08:20 (207 KB/s) - “corpus/xml/test/Mean GreansII.xml” salvo [86921/86921]
#
# --2022-06-16 17:08:20--  https://effendi.me/jazz/repo/I/Midnight%20Blue.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 69742 (68K) [application/xml]
# Salvando em: “corpus/xml/test/Midnight Blue.xml”
#
# Midnight Blue.xml   100%[===================>]  68,11K   354KB/s    em 0,2s
#
# 2022-06-16 17:08:20 (354 KB/s) - “corpus/xml/test/Midnight Blue.xml” salvo [69742/69742]
#
# --2022-06-16 17:08:20--  https://effendi.me/jazz/repo/I/MoBetterII.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 27406 (27K) [application/xml]
# Salvando em: “corpus/xml/test/MoBetterII.xml”
#
# MoBetterII.xml      100%[===================>]  26,76K  --.-KB/s    em 0,002s
#
# 2022-06-16 17:08:21 (14,9 MB/s) - “corpus/xml/test/MoBetterII.xml” salvo [27406/27406]
#
# --2022-06-16 17:08:21--  https://effendi.me/jazz/repo/I/More%20Soul%20Than%20soulful.xml
# Reaproveitando a conexão existente para effendi.me:443.
# A requisição HTTP foi enviada, aguardando resposta... ^C

# %% [markdown]
# ## Music 21
# Testing music21 to generate midi files:

# %%
import music21

# %%
corpus_folder = 'corpus/xml'
for file in os.listdir(corpus_folder):
#     print(file.split('.')[0])
    try:
        song = music21.converter.parse(corpus_folder + '/' + file)
        title = file.split('.')[0]
        song.write('midi', 'corpus/midi_music21/' + title + '.mid')
        print(title)
    except:
        pass
# Out:
# Sham Time
# Mr
# 630blues
# WaltzInA,A
# TheOddCouple
# JumpinWithSymphonySid
# BeiMir
# CrossRiver
# James Bond
# MessAround
# Blues A La Mode
# LetItFlow
# Atchafalaya
# AtchFalaya
# This Here
# AloneIntheMorning
# ThatIsWhyYouAreOverweight
# HomeFires
# Chill
# WaynesThang
# Afrodisia
# stlouisblues
# Number9
# ItCouldHappenToYou
# Ambidextrous
# Tricotism
# Satin Doll
# Sir Duke
# Sir Duke
# Skate U
# Something Else
# Soulful Strut
# Soulville
# Sticky July
# Stutter
# Summer Samba
# Take the A Train
# The Zone
# There Will Never Be Another You
# To The Top
# Woody' n' You
# People Make the World Go 'Round

# %%
c = music21.converter.parse('https://effendi.me/jazz/repo/III/Gillette.xml')
# c.show('musicxml.pdf')
c.show('midi')
# Out:
#                 <div id='midiPlayerDiv695'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv695');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# ## Creating database

# %% [markdown]
# ### mysql

# %%
import mysql.connector
from getpass import getpass
import pickle

# %%
password = getpass()

mydb = mysql.connector.connect(
  host='127.0.0.1',
  user="root",
  password=password
)

mycursor = mydb.cursor()

# listing existing databases
mycursor.execute("SHOW DATABASES")

dbs = []
for x in mycursor:
    dbs.append(x)
    
    
# checking if "songs" already exists
if ('songs',) in dbs:
    pass
else: 
    mycursor.execute("CREATE DATABASE songs")
# Out:
# ········

# %% [markdown]
# Creating first table, with raw_signals of our songs:

# %%
# mycursor.execute('''
#           CREATE TABLE IF NOT EXISTS raw_signal
#           ([raw_signal_id] INTEGER PRIMARY KEY, [signal] BLOB)
#           ''')
                     
    
songs_db =  mysql.connector.connect(host="localhost",
                                    user="root",
                                    password=getpass(),
                                    database="songs"
)

songs_cursor = songs_db.cursor()
# dropping raw_signal table if already exists.
songs_cursor.execute("DROP TABLE IF EXISTS raw_signal")
songs_cursor.execute('''CREATE TABLE raw_signal (raw_signal_id INT AUTO_INCREMENT PRIMARY KEY,
                                                title VARCHAR(255) NOT NULL, 
                                                raw_signal BLOB,
                                                original_db VARCHAR(255) NOT NULL)''')
# Out:
# ········

# %%
songs_cursor.execute("SHOW TABLES")

for x in songs_cursor:
    print(x)
# Out:
# ('raw_signal',)

# %% [markdown]
# ### Adding data to database

# %%
type(song)
# Out:
# music21.stream.Score

# %% [markdown]
# #### 28/03
# Oi! Deu errado aqui... pensar num formato pra armazenar as músicas (xml mesmo? arquivo de audio tipo wav? pickle?)

# %%
for url in url_list:
    song = music21.converter.parse(url)
    title = song.metadata.title
#     song.write('midi', 'corpus/midi_music21/' + title + '.mid')



    sql = "INSERT INTO raw_signal (title, raw_signal, original_db) VALUES (%s, %s, %s)"
    val = (title, song, url)
    songs_cursor.execute(sql, val)

    songs_db.commit()

    print(songs_cursor.rowcount, "record inserted.")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# <ipython-input-39-f3579eb0fde5> in <module>
#      10     sql = "INSERT INTO raw_signal (title, raw_signal, original_db) VALUES (%s, %s, %s)"
#      11     val = (title, song, url)
# ---> 12     songs_cursor.execute(sql, val)
#      13
#      14     songs_db.commit()
#
# /usr/local/lib/python3.8/dist-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     255
#     256         if params:
# --> 257             prepared = self._cnx.prepare_for_mysql(params)
#     258             if isinstance(prepared, dict):
#     259                 for key, value in prepared.items():
#
# /usr/local/lib/python3.8/dist-packages/mysql/connector/connection_cext.py in prepare_for_mysql(self, params)
#     670                 ]
#     671             else:
# --> 672                 result = self._cmysql.convert_to_mysql(*params)
#     673         elif isinstance(params, dict):
#     674             result = {}
#
# MySQLInterfaceError: Python type Score cannot be converted
