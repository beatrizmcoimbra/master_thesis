# %%
import os

# %%
# file_in = 'Ballad.mid'
# file_out = 'Ballad.wav'

for file in os.listdir('corpus/midi_music21'):
    
    name = file.split('.')[0]
    # !timidity corpus/midi_music21/"$name".mid -Ow -o corpus/wav_music21/"$name".wav
    print(file, name)
    print('-----------------------------------------------------------------------------------')
    print('-----------------------------------------------------------------------------------')
# Out:
# Playing corpus/midi_music21/gonehomeC#.mid
# MIDI file: corpus/midi_music21/gonehomeC#.mid
# Format: 1  Tracks: 1  Divisions: 1024
# Sequence: MusicXML Part
# Playing time: ~41 seconds
# Notes cut: 0
# Notes lost totally: 0
# gonehomeC#.mid gonehomeC#
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# Playing corpus/midi_music21/Blues For Junior.mid
# MIDI file: corpus/midi_music21/Blues For Junior.mid
# Format: 1  Tracks: 1  Divisions: 1024
# Sequence: MusicXML Part
# Playing time: ~30 seconds
# Notes cut: 0
# Notes lost totally: 0
# Blues For Junior.mid Blues For Junior
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
# Playing corpus/midi_music21/Hudson.mid
# MIDI file: corpus/midi_music21/Hudson.mid
# ...
