# %%
from musicir.rhythm.generate import Euclid, RhythmViewer
from musicir.rhythm import generate
from collections import Counter
# %matplotlib inline

# %%
ritmos_dict = {}
for rhy in generate.traditional_rhythms.items():
    notas = rhy[1].beat[0].notes
    ritmos_dict[rhy[0]] =  len(notas)
    
ritmos_dict
# Out:
# {'fandango': 4,
#  'cueca': 2,
#  'khafif-e-ramal': 2,
#  'cumbia': 3,
#  'calypso': 3,
#  'khalif-e-saghil': 3,
#  'khafif-e-ramal_2': 3,
#  'ruchenitza': 3,
#  'tresillo': 3,
#  'ruchenitza_2': 4,
#  'aksak': 4,
#  'outside_now': 4,
#  'york-samai': 5,
#  'Nawakhat': 5,
#  'cinquillo': 5,
#  'spanish_tango': 5,
#  'al-saghil-al-sani': 5,
#  'agsag-samai': 5,
#  'venda': 5,
#  'pictures_at_an_exhibition': 5,
#  'venda_clapping': 5,
#  'bossa-nova': 5,
#  'bendir': 7,
#  'mpre': 7,
#  'samba': 7,
#  'agogo-samba': 9,
#  'ngbaka-maibo': 9,
#  'aka': 11,
#  'aka_upper_sangha': 13}

# %%
ritmos = {ritmo: n_ataques for ritmo, n_ataques in ritmos_dict.items() if n_ataques >= 4}
ritmos
# Out:
# {'fandango': 4,
#  'ruchenitza_2': 4,
#  'aksak': 4,
#  'outside_now': 4,
#  'york-samai': 5,
#  'Nawakhat': 5,
#  'cinquillo': 5,
#  'spanish_tango': 5,
#  'al-saghil-al-sani': 5,
#  'agsag-samai': 5,
#  'venda': 5,
#  'pictures_at_an_exhibition': 5,
#  'venda_clapping': 5,
#  'bossa-nova': 5,
#  'bendir': 7,
#  'mpre': 7,
#  'samba': 7,
#  'agogo-samba': 9,
#  'ngbaka-maibo': 9,
#  'aka': 11,
#  'aka_upper_sangha': 13}

# %%
Euclid('fandango')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-d70033722f0d> in <module>
# ----> 1 Euclid('fandango')
#
# TypeError: __init__() missing 1 required positional argument: 'length'

# %%
for i in generate.traditional_rhythms.items():
    n_1 = Counter(str(i[1]))['X']
    n_2 = len(str(i[1]))
    if n_1 >= 4:
        print(i, n_1, n_2)
        E = Euclid(n_1, n_2)
        E.beat.show()
        print('----------------------------------------------')
# Out:
# ('fandango', X..X..X..X..) 4 12
# ----------------------------------------------
# ('ruchenitza_2', X.X.X.X) 4 7
# ----------------------------------------------
# ('aksak', X.X.X.X..) 4 9
# ----------------------------------------------
# ('outside_now', X..X..X..X.) 4 11
# ----------------------------------------------
# ('york-samai', X.XXXX) 5 6
# ----------------------------------------------
# ('Nawakhat', X.XX.XX) 5 7
# ----------------------------------------------
# ('cinquillo', X.XX.XX.) 5 8
# ----------------------------------------------
# ('spanish_tango', X.XX.XX.) 5 8
# ----------------------------------------------
# ('al-saghil-al-sani', X.XX.XX.) 5 8
# ----------------------------------------------
# ('agsag-samai', X.X.X.X.X) 5 9
# ----------------------------------------------
# ('venda', X.X.X.X.X) 5 9
# ----------------------------------------------
# ('pictures_at_an_exhibition', X.X.X.X.X..) 5 11
# ----------------------------------------------
# ('venda_clapping', X..X.X..X.X.) 5 12
# ----------------------------------------------
# ('bossa-nova', X..X..X..X..X...) 5 16
# ----------------------------------------------
# ('bendir', X.XXXXXX) 7 8
# ----------------------------------------------
# ('mpre', X.XX.X.XX.X.) 7 12
# ----------------------------------------------
# ('samba', X..X.X.X..X.X.X.) 7 16
# ----------------------------------------------
# ('agogo-samba', X.XX.X.X.XX.X.X.) 9 16
# ----------------------------------------------
# ('ngbaka-maibo', X.XX.X.X.XX.X.X.) 9 16
# ----------------------------------------------
# ('aka', X..X.X.X.X.X..X.X.X.X.X.) 11 24
# ----------------------------------------------
# ('aka_upper_sangha', X.XX.X.X.X.X.XX.X.X.X.X.) 13 24
# ----------------------------------------------

# %%
Euclid(3,4)
# Out:
# X.XX
